# %% [markdown]
# <div style="text-align: right;">
#
# # Лабораторна робота № 6
# ## Виконала Денисенко Анастасія, ФІ-21
#
# </div>

# %% [markdown]
# ## Step 0
#
# ### Run the necessary imports.

# %%
import dlib
import matplotlib.pyplot as plt
import random
import cv2

# %% [markdown]
# ## Step 1
#
# ### Load an image (any image that contains faces).

# %%
img1 = cv2.cvtColor(cv2.imread("photo1.jpg"), cv2.COLOR_BGR2RGB)
img2 = cv2.cvtColor(cv2.imread("photo2.jpg"), cv2.COLOR_BGR2RGB)
img3 = cv2.cvtColor(cv2.imread("photo3.jpg"), cv2.COLOR_BGR2RGB)
img4 = cv2.cvtColor(cv2.imread("photo4.jpg"), cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(7, 7))

plt.subplot(221)
plt.imshow(img1)
plt.axis("off")

plt.subplot(222)
plt.imshow(img2)
plt.axis("off")

plt.subplot(223)
plt.imshow(img3)
plt.axis("off")

plt.subplot(224)
plt.imshow(img4)
plt.axis("off")

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Step 2
#
# ### Load the dlib face predictor.

# %%
detector = dlib.get_frontal_face_detector()
predictor = dlib.shape_predictor("shape_predictor_68_face_landmarks.dat")

# %%
def detect_faces(img):
    # Copy image
    image_copy = img.copy()
    # Detect faces
    faces = detector(image_copy)
    print(f"Detected {len(faces)} face(s)")

    # Draw bounding box for each face
    for face in faces:
        color = (random.randint(0,255), random.randint(0,255), random.randint(0,255))
        x1, y1 = face.left(), face.top()
        x2, y2 = face.right(), face.bottom()

        cv2.rectangle(image_copy, (x1, y1), (x2, y2), color, 2)

    # Display result
    plt.figure(figsize=(8,8))
    plt.imshow(image_copy)
    plt.title(f"Faces detected: {len(faces)}")
    plt.axis("off")
    plt.show()
    
    return len(faces)

# %% [markdown]
# ## Step 3
#
# ### Run the predictor on your image.
#
# ## Step 4
#
# ### Draw bounding boxes around the detected faces and plot the image. Use different colour for each face.

# %%
_ = detect_faces(img1)
# Out:
# Detected 1 face(s)

# %% [markdown]
# ## Step 5 (optional)
#
# ### Repeat the process with a different and more challenging image (more faces, smaller faces, people with glasses, hats, helmets, etc.). How does the detector perform? Is it robust?

# %%
_ = detect_faces(img2)
# Out:
# Detected 1 face(s)

# %%
_ = detect_faces(img3)
# Out:
# Detected 6 face(s)

# %%
_ = detect_faces(img4)
# Out:
# Detected 0 face(s)
